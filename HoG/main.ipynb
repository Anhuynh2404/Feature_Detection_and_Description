# %%
from PIL import Image
import HOG
import matplotlib.pyplot as plt
import numpy as np

# %%
image_path = "/home/an/an_workplace/Lab_CV/Data/saka.png"
try:
    Image.open(image_path)
except FileNotFoundError:
    print(f"File not found: {image_path}")

img_loaded = HOG.load_and_preprocess_image(image_path)

# %%
if img_loaded is not None:
    plt.imshow(img_loaded, cmap='gray')  
    plt.title("Grayscale Image (Normalized)")
    plt.axis('off') 
    plt.show()
else:
    print("Image could not be loaded.")

# %%
gradient_y, gradient_x = HOG.gradient(img_loaded)

# %%
print("Gradient Y1:", gradient_y)
print("Gradient X1:", gradient_x)
# Out:
# Gradient Y1: [[-0.00392157  0.20784314  0.29607843 ...  0.0254902   0.02745098
#    0.        ]
#  [-0.01568627  0.09607843  0.46862745 ...  0.0254902   0.02745098
#    0.        ]
#  [ 0.          0.01960784  0.24313725 ...  0.02352941  0.0254902
#    0.        ]
#  ...
#  [-0.04313725  0.00196078  0.03137255 ...  0.12352941  0.14509804
#    0.01568627]
#  [-0.01568627  0.05098039  0.01568627 ...  0.11372549  0.12745098
#    0.02352941]
#  [-0.02745098  0.00588235  0.01568627 ...  0.03529412  0.04117647
#    0.00392157]]
# Gradient X1: [[ 0.00392157 -0.00784314 -0.10980392 ...  0.          0.
#    0.        ]
#  [ 0.04313725  0.04509804 -0.0627451  ...  0.03137255  0.02745098
#    0.02745098]
#  [ 0.0372549   0.04509804  0.01176471 ...  0.03529412  0.03137255
#    0.02745098]
#  ...
#  [ 0.17843137  0.15882353  0.14117647 ...  0.01372549  0.03921569
#    0.05098039]
#  [ 0.36666667  0.36078431  0.18823529 ... -0.09803922 -0.07647059
#   -0.08039216]
# ...

# %%
abs_grad_mag = HOG.caculation_gradient_magnitude(gradient_x, gradient_y)
titles = ['X-gradient', 'Y-gradient', 'Gradient Magnitude']
images = [gradient_x, gradient_y, abs_grad_mag]

plt.figure(figsize=(12, 4))
for i in range(3):
    plt.subplot(1, 3, i+1)
    plt.imshow(images[i], cmap='gray')
    plt.title(titles[i])
    plt.axis('off')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Test

# %%
horizontal_mask = np.array([-1, 0, 1])
vertical_mask = np.array([[-1],
                             [0],
                             [1]])
